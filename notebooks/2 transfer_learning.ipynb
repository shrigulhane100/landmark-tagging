# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for Landmark Classification
#
#
# ### Transfer learning
#
# In the previous notebook we have trained our own CNN and we got a certain performance. Let's see how hard it is to match that performance with transfer learning.
#
# ---
# ## <img src="../static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 0: Setting up
#
# The following cells make sure that your environment is setup correctly and check that your GPU is available and ready to go. You have to execute them every time you restart your notebook.

# %%
# Install requirements
# !pip install -r requirements.txt 
# | grep -v "already satisfied"
# Out:
# Collecting opencv-python-headless (from -r requirements.txt (line 1))
#   Downloading opencv_python_headless-4.8.0.76-cp37-abi3-win_amd64.whl (38.0 MB)
#      ---------------------------------------- 38.0/38.0 MB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 2)) (3.5.3)
# Requirement already satisfied: numpy in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 3)) (1.23.5)
# Requirement already satisfied: pillow in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 4)) (9.5.0)
# Collecting bokeh (from -r requirements.txt (line 5))
#   Downloading bokeh-3.2.1-py3-none-any.whl (7.8 MB)
#      ---------------------------------------- 7.8/7.8 MB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: torch in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 6)) (1.13.1+cu116)
# Requirement already satisfied: torchvision in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 7)) (0.14.1+cu116)
# Requirement already satisfied: tqdm in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 8)) (4.64.1)
# Requirement already satisfied: ipywidgets in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 9)) (8.0.2)
# Collecting livelossplot (from -r requirements.txt (line 10))
#   Using cached livelossplot-0.5.5-py3-none-any.whl (22 kB)
# Collecting pytest (from -r requirements.txt (line 11))
#   Downloading pytest-7.4.0-py3-none-any.whl (323 kB)
#      -------------------------------------- 323.6/323.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 12)) (1.5.2)
# Requirement already satisfied: seaborn in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 2)) (4.37.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bokeh->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bokeh->-r requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bokeh->-r requirements.txt (line 5)) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bokeh->-r requirements.txt (line 5)) (6.2)
# Collecting xyzservices>=2021.09.1 (from bokeh->-r requirements.txt (line 5))
#   Downloading xyzservices-2023.7.0-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.7/56.7 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->-r requirements.txt (line 6)) (4.3.0)
# Requirement already satisfied: requests in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torchvision->-r requirements.txt (line 7)) (2.28.1)
# Requirement already satisfied: colorama in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm->-r requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets->-r requirements.txt (line 9)) (6.15.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets->-r requirements.txt (line 9)) (8.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets->-r requirements.txt (line 9)) (5.4.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets->-r requirements.txt (line 9)) (4.0.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets->-r requirements.txt (line 9)) (3.0.3)
# Collecting iniconfig (from pytest->-r requirements.txt (line 11))
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting pluggy<2.0,>=0.12 (from pytest->-r requirements.txt (line 11))
#   Downloading pluggy-1.2.0-py3-none-any.whl (17 kB)
# Collecting exceptiongroup>=1.0.0rc8 (from pytest->-r requirements.txt (line 11))
#   Downloading exceptiongroup-1.1.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pytest->-r requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->-r requirements.txt (line 12)) (2022.2.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 9)) (1.6.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 9)) (7.3.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 9)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 9)) (1.5.5)
# Requirement already satisfied: psutil in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 9)) (5.9.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 9)) (24.0.0)
# Requirement already satisfied: backcall in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from Jinja2>=2.9->bokeh->-r requirements.txt (line 5)) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 2)) (1.12.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->torchvision->-r requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->torchvision->-r requirements.txt (line 7)) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->torchvision->-r requirements.txt (line 7)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->torchvision->-r requirements.txt (line 7)) (2022.9.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 9)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 9)) (4.11.1)
# Requirement already satisfied: wcwidth in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.2.5)
# Requirement already satisfied: executing in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: asttokens in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (2.0.8)
# Requirement already satisfied: pure-eval in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\shrig\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 9)) (304)
# Installing collected packages: xyzservices, pluggy, opencv-python-headless, iniconfig, exceptiongroup, pytest, bokeh, livelossplot
# Successfully installed bokeh-3.2.1 exceptiongroup-1.1.2 iniconfig-2.0.0 livelossplot-0.5.5 opencv-python-headless-4.8.0.76 pluggy-1.2.0 pytest-7.4.0 xyzservices-2023.7.0
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\shrig\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from src.helpers import setup_env

# If running locally, this will download dataset (make sure you have at 
# least 2 Gb of space on your hard drive)
setup_env()
# Out:
# GPU available
# Dataset already downloaded. If you need to re-download, please delete the directory landmark_images
# Reusing cached mean and std

# %% [markdown]
# ---
# ## <img src="../static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 1: Create transfer learning architecture
#
# Open the file `src/transfer.py` and complete the `get_model_transfer_learning` function. When you are done, execute this test:

# %%
# !pytest -vv src/transfer.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.11, pytest-7.4.0, pluggy-1.2.0 -- C:\Users\shrig\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe
# cachedir: .pytest_cache
# rootdir: d:\project\home
# plugins: anyio-3.6.1
# collecting ... collected 1 item
#
# src/transfer.py::test_get_model_transfer_learning FAILED                 [100%]
#
# ================================== FAILURES ===================================
# ______________________ test_get_model_transfer_learning _______________________
#
# data_loaders = {'test': <torch.utils.data.dataloader.DataLoader object at 0x000001E6780AC880>, 'train': <torch.utils.data.dataloader.DataLoader object at 0x000001E6780AC6D0>, 'valid': <torch.utils.data.dataloader.DataLoader object at 0x000001E6780AC640>}
#
#     def test_get_model_transfer_learning(data_loaders):
#
#         model = get_model_transfer_learning(n_classes=23)
#
#         dataiter = iter(data_loaders["train"])
# >       images, labels = dataiter.next()
# E       AttributeError: '_SingleProcessDataLoaderIter' object has no attribute 'next'
#
# src\transfer.py:62: AttributeError
# ---------------------------- Captured stdout setup ----------------------------
# Reusing cached mean and std
# Dataset mean: tensor([0.4638, 0.4725, 0.4687]), std: tensor([0.2699, 0.2706, 0.3018])
# ---------------------------- Captured stderr call -----------------------------
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\shrig/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
#
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
#   2%|▏         | 848k/44.7M [00:00<00:05, 8.67MB/s]
#   4%|▍         | 1.94M/44.7M [00:00<00:04, 10.0MB/s]
#   6%|▋         | 2.89M/44.7M [00:00<00:05, 7.33MB/s]
#   8%|▊         | 3.66M/44.7M [00:00<00:05, 7.54MB/s]
#  10%|▉         | 4.42M/44.7M [00:00<00:05, 7.36MB/s]
#  12%|█▏        | 5.15M/44.7M [00:00<00:06, 6.78MB/s]
#  13%|█▎        | 5.82M/44.7M [00:00<00:06, 6.34MB/s]
#  14%|█▍        | 6.45M/44.7M [00:00<00:06, 6.38MB/s]
#  16%|█▌        | 7.07M/44.7M [00:01<00:06, 6.34MB/s]
#  17%|█▋        | 7.69M/44.7M [00:01<00:06, 6.21MB/s]
#  19%|█▊        | 8.29M/44.7M [00:01<00:06, 6.00MB/s]
#  20%|█▉        | 8.92M/44.7M [00:01<00:06, 6.13MB/s]
#  21%|██▏       | 9.52M/44.7M [00:01<00:06, 5.95MB/s]
#  23%|██▎       | 10.1M/44.7M [00:01<00:06, 5.90MB/s]
#  24%|██▍       | 10.7M/44.7M [00:01<00:06, 5.83MB/s]
#  25%|██▌       | 11.3M/44.7M [00:01<00:06, 5.70MB/s]
#  27%|██▋       | 11.9M/44.7M [00:01<00:05, 5.75MB/s]
#  28%|██▊       | 12.6M/44.7M [00:02<00:05, 6.14MB/s]
#  30%|██▉       | 13.2M/44.7M [00:02<00:05, 5.80MB/s]
#  31%|███       | 13.9M/44.7M [00:02<00:05, 6.15MB/s]
#  32%|███▏      | 14.5M/44.7M [00:02<00:05, 6.13MB/s]
#  34%|███▍      | 15.2M/44.7M [00:02<00:04, 6.38MB/s]
#  35%|███▌      | 15.8M/44.7M [00:02<00:04, 6.10MB/s]
#  37%|███▋      | 16.4M/44.7M [00:02<00:05, 5.77MB/s]
#  38%|███▊      | 17.0M/44.7M [00:02<00:04, 5.99MB/s]
#  39%|███▉      | 17.6M/44.7M [00:02<00:04, 5.95MB/s]
#  41%|████      | 18.2M/44.7M [00:03<00:04, 5.80MB/s]
#  42%|████▏     | 18.7M/44.7M [00:03<00:04, 5.78MB/s]
#  43%|████▎     | 19.4M/44.7M [00:03<00:04, 6.11MB/s]
#  45%|████▍     | 20.0M/44.7M [00:03<00:04, 6.11MB/s]
#  46%|████▌     | 20.6M/44.7M [00:03<00:04, 5.73MB/s]
#  48%|████▊     | 21.3M/44.7M [00:03<00:04, 5.82MB/s]
#  49%|████▉     | 21.9M/44.7M [00:03<00:04, 5.81MB/s]
#  51%|█████     | 22.6M/44.7M [00:03<00:03, 5.89MB/s]
#  52%|█████▏    | 23.3M/44.7M [00:03<00:03, 6.26MB/s]
#  53%|█████▎    | 23.9M/44.7M [00:04<00:03, 6.24MB/s]
#  55%|█████▍    | 24.5M/44.7M [00:04<00:03, 6.19MB/s]
#  56%|█████▌    | 25.1M/44.7M [00:04<00:03, 6.18MB/s]
#  57%|█████▋    | 25.7M/44.7M [00:04<00:03, 5.78MB/s]
#  59%|█████▊    | 26.2M/44.7M [00:04<00:03, 5.79MB/s]
#  60%|█████▉    | 26.8M/44.7M [00:04<00:03, 5.47MB/s]
#  62%|██████▏   | 27.6M/44.7M [00:04<00:02, 6.28MB/s]
#  63%|██████▎   | 28.2M/44.7M [00:04<00:02, 6.17MB/s]
#  65%|██████▍   | 28.8M/44.7M [00:04<00:02, 5.97MB/s]
#  66%|██████▌   | 29.4M/44.7M [00:05<00:02, 5.89MB/s]
#  67%|██████▋   | 30.1M/44.7M [00:05<00:02, 6.20MB/s]
#  69%|██████▉   | 30.8M/44.7M [00:05<00:02, 6.06MB/s]
#  70%|███████   | 31.4M/44.7M [00:05<00:02, 6.06MB/s]
#  72%|███████▏  | 32.0M/44.7M [00:05<00:02, 5.90MB/s]
#  73%|███████▎  | 32.7M/44.7M [00:05<00:02, 5.79MB/s]
#  75%|███████▍  | 33.4M/44.7M [00:05<00:02, 5.82MB/s]
#  76%|███████▋  | 34.1M/44.7M [00:05<00:01, 6.27MB/s]
#  78%|███████▊  | 34.7M/44.7M [00:05<00:01, 6.27MB/s]
#  79%|███████▉  | 35.3M/44.7M [00:06<00:01, 5.74MB/s]
#  80%|████████  | 35.9M/44.7M [00:06<00:01, 5.77MB/s]
#  82%|████████▏ | 36.7M/44.7M [00:06<00:01, 6.23MB/s]
#  83%|████████▎ | 37.3M/44.7M [00:06<00:01, 5.97MB/s]
#  85%|████████▍ | 37.8M/44.7M [00:06<00:01, 5.97MB/s]
#  86%|████████▌ | 38.4M/44.7M [00:06<00:01, 5.97MB/s]
#  88%|████████▊ | 39.1M/44.7M [00:06<00:00, 6.16MB/s]
#  89%|████████▉ | 39.7M/44.7M [00:06<00:00, 5.96MB/s]
#  90%|█████████ | 40.3M/44.7M [00:06<00:00, 6.10MB/s]
#  92%|█████████▏| 40.9M/44.7M [00:07<00:00, 5.89MB/s]
#  93%|█████████▎| 41.7M/44.7M [00:07<00:00, 5.73MB/s]
#  95%|█████████▍| 42.3M/44.7M [00:07<00:00, 5.86MB/s]
#  96%|█████████▌| 42.9M/44.7M [00:07<00:00, 5.62MB/s]
#  98%|█████████▊| 43.7M/44.7M [00:07<00:00, 6.33MB/s]
#  99%|█████████▉| 44.4M/44.7M [00:07<00:00, 6.32MB/s]
# 100%|██████████| 44.7M/44.7M [00:07<00:00, 6.11MB/s]
# ============================== warnings summary ===============================
# src/transfer.py::test_get_model_transfer_learning
#   C:\Users\shrig\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#     warnings.warn(
#
# src/transfer.py::test_get_model_transfer_learning
#   C:\Users\shrig\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#     warnings.warn(msg)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ===========================
# FAILED src/transfer.py::test_get_model_transfer_learning - AttributeError: '_...
# ======================= 1 failed, 2 warnings in 11.42s ========================

# %% [markdown]
# ---
# ## <img src="../static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 2: Train, validation and test
#
# Let's train our transfer learning model! Let's start defining the hyperparameters:

# %%
batch_size = 64  # size of the minibatch for stochastic gradient descent (or Adam)
valid_size = 0.2  # fraction of the training data to reserve for validation
num_epochs = 30  # number of epochs for training
num_classes = 50  # number of classes. Do not change this
learning_rate = 0.001  # Learning rate for SGD (or Adam)
opt = 'adam'      # optimizer. 'sgd' or 'adam'
weight_decay = 0.0 # regularization. Increase this to combat overfitting

# %%
from src.data import get_data_loaders
from src.optimization import get_optimizer, get_loss
from src.train import optimize
from src.transfer import get_model_transfer_learning

# Get a model using get_model_transfer_learning. Use one of the names reported here:
# https://pytorch.org/vision/0.10/models.html
# For example, if you want to load ResNet 18, use "resnet18"
# NOTE: use the hyperparameters defined in the previous cell, do NOT copy/paste the
# values
model_transfer = get_model_transfer_learning(model_name="resnet50", n_classes=50)        

# with active_session():
    # train the model
data_loaders = get_data_loaders(batch_size=batch_size)
optimizer = get_optimizer(
    model_transfer,
    learning_rate=learning_rate,
    optimizer=opt,
    weight_decay=weight_decay,
)
loss = get_loss()

optimize(
    data_loaders,
    model_transfer,
    optimizer,
    loss,
    n_epochs=num_epochs,
    save_path="checkpoints/model_transfer.pt",
    interactive_tracking=True
)

# %% [markdown]
# <img src="static_images/icons/noun-question-mark-869751.png" alt="?" style="width:25px"/> __Question:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# <img src="static_images/icons/noun-answer-3361020.png" alt=">" style="width:25px"/>  __Answer:__ I decided to use ResNet18 for the base of my model, since it performs fairly well on ImageNet and is not too large of a model. Also, since ResNet18 was trained for the ImageNet task, it is a good model to use for this landmark classificaiton task, since both ImageNet and this landmark task use images of natural scenes.

# %% [markdown]
# Now play with the hyperparameters and see which performance you can get on the validation set. You should get at least 60% for a passing grade, but a good model choice and a good training strategy could get you up to 80% or so. Let's see how close you can get!

# %% [markdown]
# ---
# ## <img src="../static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 3: Test the Model
#
# Try out your model on the test dataset of landmark images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60% and matches more or less what you got on the validation set (otherwise you're overfitting!)

# %%
import torch
from src.train import one_epoch_test
from src.transfer import get_model_transfer_learning

model_transfer = get_model_transfer_learning("resnet50", n_classes=num_classes)
# Load saved weights
model_transfer.load_state_dict(torch.load('checkpoints/model_transfer.pt'), strict=False)

one_epoch_test(data_loaders['test'], model_transfer, loss)
# Out:
# Testing: 100%|██████████████████████████████████| 20/20 [00:44<00:00,  2.21s/it]
# Test Loss: 1.054592
#
#
# Test Accuracy: 71% (894/1250)
# 1.054591736197472

# %% [markdown]
# ---
# ## <img src="../static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 4: Export using torchscript
#
# Now, just like we did with our original model, we export the best fit model using torchscript so that it can be used in our application:

# %%
from src.predictor import Predictor
from src.helpers import compute_mean_and_std

# First let's get the class names from our data loaders
class_names = data_loaders["train"].dataset.classes

# Then let's move the model_transfer to the CPU
# (we don't need GPU for inference)
model_transfer = model_transfer.cpu()
# Let's make sure we use the right weights by loading the
# best weights we have found during training
# NOTE: remember to use map_location='cpu' so the weights
# are loaded on the CPU (and not the GPU)
model_transfer.load_state_dict(
    torch.load("checkpoints/model_transfer.pt", map_location="cpu")
)

# Let's wrap our model using the predictor class
mean, std = compute_mean_and_std()
predictor = Predictor(model_transfer, class_names, mean, std).cpu()

# Export using torch.jit.script
scripted_predictor = torch.jit.script(predictor)
scripted_predictor.save("checkpoints/transfer_exported.pt")
# Out:
# Reusing cached mean and std

# %%
import torch
from src.predictor import predictor_test
from src.helpers import plot_confusion_matrix

model_reloaded = torch.jit.load("checkpoints/transfer_exported.pt")

pred, truth = predictor_test(data_loaders['test'], model_reloaded)

plot_confusion_matrix(pred, truth)
# Out:
#   0%|                                          | 1/1250 [00:00<14:02,  1.48it/s]C:\Users\shrig\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\nn\modules\module.py:1194: UserWarning: operator () profile_node %353 : int = prim::profile_ivalue(%out_dtype.1)
#  does not have profile information (Triggered internally at ..\torch\csrc\jit\codegen\cuda\graph_fuser.cpp:109.)
#   return forward_call(*input, **kwargs)
# 100%|███████████████████████████████████████| 1250/1250 [02:09<00:00,  9.68it/s]
# Accuracy: 0.0584
